# %%
import pandas as pd

# We will start by looking at the contents of the data to get an idea of what is inside and if it will be useful.
# Default return of 5.
def open_and_return_csv_head(filepath, n_return=5):
    stormdf = pd.read_csv(filepath, encoding='unicode_escape')

    # Drop NaN values.
    stormdf = stormdf.dropna(axis='columns')
    return stormdf.head(n_return)

data_dir = "../data/stormdata/details"
stormdata_1996_name = "StormEvents_details-ftp_v1.0_d1966_c20210803.csv"
filepath = data_dir + "/" + stormdata_1996_name

# Look at stormdata....csv files first. Nothing super useful here, we are looking for coordinates. 
open_and_return_csv_head(filepath, 10)
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           196609          5         830         196609        5       830
# 1           196607         11        2118         196607       11      2118
# 2           196607          6        1900         196607        6      1900
# 3           196605         26        1900         196605       26      1900
# 4           196608          5        2300         196608        5      2300
# 5           196611         16        1315         196611       16      1315
# 6           196605         30        1600         196605       30      1600
# 7           196610         14        1400         196610       14      1400
# 8           196606          9        2000         196606        9      2000
# 9           196604         19        1908         196604       19      1908
#
#    EVENT_ID       STATE  STATE_FIPS  YEAR  ... DAMAGE_PROPERTY DAMAGE_CROPS  \
# ...
